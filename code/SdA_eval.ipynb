# %% [markdown]
# # Stacked Denoising Autoencoder(SdA) の評価(Eval)スクリプト

# %% [markdown]
# ## SdA復元 (層サイズ: (28*28) --> 1024 --> 1024 --> 1024 --> 10)

# %%
weight_file_path='SdA_plots/weights'
dataset='mnist.pkl.gz'

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.cm as cm
# %matplotlib inline
import numpy
import theano
import theano.tensor as T
import math
import sys
from theano.tensor.shared_randomstreams import RandomStreams
from utils import tile_raster_images
from logistic_sgd import load_data
from SdA import SdA
import cPickle

# Random Generators
rng = numpy.random.RandomState(123)
theano_rng = RandomStreams(rng.randint(2 ** 30))

# DBN 初期化
sda = SdA(numpy_rng=rng, theano_rng = theano_rng,
                   n_ins=28 * 28, hidden_layers_sizes=[1024, 1024, 1024], n_outs=10 )

# 重み読み込み
weights = open(weight_file_path)
for p in sda.params:
    p.set_value(cPickle.load(weights), borrow=True)
weights.close()

# DBN 評価関数
x = T.matrix('x')
sda_eval = theano.function([ x ], 
                                                  sda.logLayer.y_pred,
                                                  name='sda_eval',
                                                  givens = { sda.x: x })

# データセット読み込み
datasets = load_data(dataset)
train_set_x, train_set_y = datasets[0]
valid_set_x, valid_set_y = datasets[1]
test_set_x, test_set_y = datasets[2]
# Out:
# ... loading data
# Using gpu device 0: GeForce GT 650M

# %% [markdown]
# ##復元されたSdAの中間層の表現
# ### 第1隠れ層

# %%
da = sda.dA_layers[0]
plt.imshow(tile_raster_images( X=da.W.get_value(borrow=True).T,
                                                       img_shape=(int(math.sqrt(da.n_visible)), int(math.sqrt(da.n_visible))),
                                                       tile_shape=(int(math.sqrt(da.n_hidden)), int(math.sqrt(da.n_hidden))),
                                                       tile_spacing=(1, 1)),
                    cmap = cm.Greys_r)

# %% [markdown]
# ### 第2隠れ層

# %%
da = sda.dA_layers[1]
plt.imshow(tile_raster_images( X=da.W.get_value(borrow=True).T,
                                                       img_shape=(int(math.sqrt(da.n_visible)), int(math.sqrt(da.n_visible))),
                                                       tile_shape=(int(math.sqrt(da.n_hidden)), int(math.sqrt(da.n_hidden))),
                                                       tile_spacing=(1, 1)),
                    cmap = cm.Greys_r)

# %% [markdown]
# ### 第3隠れ層

# %%
da = sda.dA_layers[2]
plt.imshow(tile_raster_images( X=da.W.get_value(borrow=True).T,
                                                       img_shape=(int(math.sqrt(da.n_visible)), int(math.sqrt(da.n_visible))),
                                                       tile_shape=(int(math.sqrt(da.n_hidden)), int(math.sqrt(da.n_hidden))),
                                                       tile_spacing=(1, 1)),
                    cmap = cm.Greys_r)

# %% [markdown]
# ## テスト入力データ表示と予測結果(最初の100例/全10000例)

# %%
input = numpy.array(test_set_x.get_value(borrow=True))
ans = numpy.array(test_set_y.eval())
plt.imshow(tile_raster_images(X=input[0:100], img_shape=(28, 28), tile_shape=(5,20), tile_spacing=(1, 1)), 
                    cmap = cm.Greys_r)

preds = sda_eval(input)
print"予測結果\n"
sys.stdout.write('       ')
for i in xrange(preds[0:100].shape[0]):
    sys.stdout.write('%d     ' % preds[i])
    if (i % 20) ==19 : sys.stdout.write('\n       ')
print "\nテストイメージ"
# Out:
# 予測結果
#
#        7     2     1     0     4     1     4     9     6     9     0     6     9     0     1     5     9     7     3     4
#        9     6     6     5     4     0     7     4     0     1     3     1     3     4     7     2     7     1     2     1
#        1     7     4     2     3     5     1     2     4     4     6     3     5     5     6     0     4     1     9     5
#        7     8     9     3     7     4     6     4     3     0     7     0     2     9     1     7     3     2     9     7
#        7     6     2     7     8     4     7     3     6     1     3     6     9     3     1     4     1     7     6     9
#
# テストイメージ

# %% [markdown]
# ## 予測エラー(すべて)

# %%
wrong_idx = numpy.where(preds!=ans)[0]
plt.imshow(tile_raster_images(X=input[wrong_idx], img_shape=(28, 28), tile_shape=(wrong_idx.shape[0]/20 + 1,20), tile_spacing=(1, 1)), 
                    cmap = cm.Greys_r)
print '予測エラー(予/実)\n'
a = ans[wrong_idx]
wrong_p = preds[wrong_idx]
sys.stdout.write('       ')
for i in xrange(wrong_idx.shape[0]):
    import sys
    sys.stdout.write('%d/%d   ' % (wrong_p[i],a[i]) )
    if (i % 20) ==19 : sys.stdout.write('\n       ')
print "\n\n予測エラーのテストイメージ"
# Out:
# 予測エラー(予/実)
#
#        6/5   2/4   7/2   3/5   0/6   5/3   0/8   2/8   1/2   3/7   8/5   9/4   5/1   9/8   4/5   0/6   5/6   6/4   2/7   4/9
#        9/4   5/9   7/5   3/8   6/5   3/5   7/8   6/4   3/2   5/6   7/3   0/8   8/5   2/7   4/9   3/5   9/4   9/7   0/2   7/3
#        9/4   1/6   6/9   9/5   1/9   8/9   4/9   4/2   3/5   0/9   1/6   4/9   9/4   3/5   7/4   0/8   2/3   5/9   3/8   9/5
#        0/6   9/7   7/3   1/9   4/6   2/3   0/5   5/8   3/9   2/7   6/4   0/2   5/6   4/9   6/5   3/1   6/4   1/7   4/9   2/0
#        0/9   7/2   8/2   3/5   4/9   7/8   5/6   2/7   5/3   6/4   3/8   4/9   4/7   6/1   3/2   3/4   0/7   3/5   8/3   8/3
#        9/5   9/3   9/3   9/8   7/9   1/7   7/0   3/8   5/9   5/8   5/0   9/8   6/1   1/2   8/2   9/3   6/0   6/8   6/8   9/4
#        2/7   2/7   5/8   4/9   1/0   7/9   7/2   6/5   0/4   0/5   4/9   7/2   8/6
#
# 予測エラーのテストイメージ
